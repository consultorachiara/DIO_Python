# %% [markdown]
# <a href="https://colab.research.google.com/github/1chiara/DIO_Python/blob/main/Projeto1_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python para finanças

# %%
# !pip install -q yfinance

# %% [markdown]
# Importar bibliotecas

# %%
import pandas as pd # trabalhar com Dataframes
import numpy as np # funções matemáticas
from pandas_datareader import data # função para carregar dados financeiros online
import matplotlib.pyplot as plt # biblioteca de visualização no Python, com gráficos estáticos
import seaborn as sns # visualização avançada de gráficos estáticos
import plotly.express as px # biblioteca para geração de gráficos interativos, com gráficos dinâmicos
import yfinance as yf

# %% [markdown]
# # Extração
#
# ## Cotação das ações do Santander

# %%
#san_df = data.DataReader(name = 'SAN.SA', data_source='yahoo', start='2015-01-01')
san_df = yf.download("SAN.MC", start='2015-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
san_df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2015-01-02  6.678141  6.707361  6.541468  6.627242   4.532897   83205286
# 2015-01-05  6.582941  6.669658  6.310537  6.324676   4.325947  113251404
# 2015-01-06  6.352953  6.383115  6.211567  6.214394   4.250518   90444216
# 2015-01-07  6.268121  6.387828  6.191772  6.253982   4.277595   80771172
# 2015-01-08  6.390656  6.483028  6.332216  6.462291   4.420074   26289975
# ...              ...       ...       ...       ...        ...        ...
# 2023-08-31  3.631500  3.646000  3.593500  3.602000   3.602000   55210602
# 2023-09-01  3.606000  3.616000  3.519500  3.519500   3.519500   29668913
# 2023-09-04  3.541000  3.564000  3.501500  3.515000   3.515000   17339932
# 2023-09-05  3.503500  3.532000  3.469500  3.503000   3.503000   21313712
# 2023-09-06  3.466000  3.477500  3.387500  3.409500   3.409500   19812314
#
# [2223 rows x 6 columns]

# %% [markdown]
# Transformação

# %%
san_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2223 entries, 2015-01-02 to 2023-09-06
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2223 non-null   float64
#  1   High       2223 non-null   float64
#  2   Low        2223 non-null   float64
#  3   Close      2223 non-null   float64
#  4   Adj Close  2223 non-null   float64
#  5   Volume     2223 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 121.6 KB

# %%
# mostra os três primeiros registros deste dataframe
san_df.head(3)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2015-01-02  6.678141  6.707361  6.541468  6.627242   4.532897   83205286
# 2015-01-05  6.582941  6.669658  6.310537  6.324676   4.325947  113251404
# 2015-01-06  6.352953  6.383115  6.211567  6.214394   4.250518   90444216

# %%
# Análise estatística

san_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2223.000000  2223.000000  2223.000000  2223.000000  2223.000000
# mean      3.872947     3.919721     3.821317     3.869759     3.211492
# std       1.173703     1.179018     1.166768     1.173455     0.740663
# min       1.444017     1.502475     1.439417     1.473533     1.356989
# 25%       3.087500     3.133500     3.042000     3.083250     2.744365
# 50%       3.675688     3.714500     3.616658     3.677500     3.162786
# 75%       4.805246     4.856025     4.742092     4.795348     3.673481
# max       6.725270     6.757317     6.678141     6.741294     4.723031
#
#              Volume
# count  2.223000e+03
# mean   7.683282e+07
# std    6.724359e+07
# min    0.000000e+00
# 25%    4.008108e+07
# 50%    5.738098e+07
# 75%    8.809197e+07
# max    9.487686e+08

# %% [markdown]
# Extração

# %%
# Salvar num arquivo csv

san_df.to_csv('san.csv')

# %%
# usar agora a base de acordo com o arquivo salvo
# Ele abriu mais uma coluna onde coloca as datas e a coluna de index mostra o número das linhas

san_df2 = pd.read_csv('/content/san.csv')
san_df2
# Out:
#             Date      Open      High       Low     Close  Adj Close     Volume
# 0     2015-01-02  6.678141  6.707361  6.541468  6.627242   4.532897   83205286
# 1     2015-01-05  6.582941  6.669658  6.310537  6.324676   4.325947  113251404
# 2     2015-01-06  6.352953  6.383115  6.211567  6.214394   4.250518   90444216
# 3     2015-01-07  6.268121  6.387828  6.191772  6.253982   4.277595   80771172
# 4     2015-01-08  6.390656  6.483028  6.332216  6.462291   4.420074   26289975
# ...          ...       ...       ...       ...       ...        ...        ...
# 2218  2023-08-31  3.631500  3.646000  3.593500  3.602000   3.602000   55210602
# 2219  2023-09-01  3.606000  3.616000  3.519500  3.519500   3.519500   29668913
# 2220  2023-09-04  3.541000  3.564000  3.501500  3.515000   3.515000   17339932
# 2221  2023-09-05  3.503500  3.532000  3.469500  3.503000   3.503000   21313712
# 2222  2023-09-06  3.466000  3.477500  3.387500  3.409500   3.409500   19812314
#
# [2223 rows x 7 columns]
